# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import torch
from torch.utils.data import Subset
import random
import requests
from transformers import AutoModel, AutoTokenizer
import nltk
from nltk.tokenize import word_tokenize

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
import os

def read_conll_file(file_path):
    sentences, ner_tags = [], []
    tokens, tags = [], []

    with open(file_path, 'r', encoding='utf-8') as f:
        for line in f:
            line = line.strip()
            if not line:
                if tokens:
                    sentences.append(tokens)
                    ner_tags.append(tags)
                    tokens, tags = [], []
                continue
            if line.startswith("#"): continue
            parts = line.split()
            if len(parts) >= 4:
                tokens.append(parts[0])
                tags.append(parts[-1])

    if tokens:
        sentences.append(tokens)
        ner_tags.append(tags)
    return sentences, ner_tags

# %%
def load_conll_dataset(data_dir):
    all_sents, all_tags = [], []
    for filename in os.listdir(data_dir):
        if filename.endswith(".conll"):
            sents, tags = read_conll_file(os.path.join(data_dir, filename))
            all_sents.extend(sents)
            all_tags.extend(tags)
    return all_sents, all_tags

# %%
def prepare_datasets(data_dir, low_resource_samples=100, seed=SEED):

    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)

    sentences, ner_tags = load_conll_dataset(data_dir)

    # Create Dataset
    dataset = Dataset.from_dict({"tokens": sentences, "ner_tags": ner_tags})

    # 100 Random Samples
    indices = list(range(len(dataset)))
    random.Random(seed).shuffle(indices)  # Seed-controlled shuffle
    train_indices = indices[:low_resource_samples]

    train_samples = [
        (dataset[i]['tokens'], dataset[i]['ner_tags'])
        for i in train_indices
    ]

    return train_samples

# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-3.5.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.12.0,>=2023.1.0 (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.15)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.30.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-3.5.0-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.2/491.2 kB 28.7 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.6 MB/s eta 0:00:00
# Downloading fsspec-2024.12.0-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 15.5 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 10.6 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 15.8 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.6.0+cu124 requires nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.5.3.2 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-cupti-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-cupti-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-nvrtc-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-nvrtc-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-runtime-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-runtime-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cudnn-cu12==9.1.0.70; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cudnn-cu12 9.3.0.75 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cufft-cu12==11.2.1.3; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cufft-cu12 11.2.3.61 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-curand-cu12==10.3.5.147; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-curand-cu12 10.3.6.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusolver-cu12==11.6.1.9; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusolver-cu12 11.6.3.83 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusparse-cu12==12.3.1.170; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusparse-cu12 12.5.1.3 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-nvjitlink-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-nvjitlink-cu12 12.5.82 which is incompatible.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2024.12.0 which is incompatible.
# Successfully installed datasets-3.5.0 dill-0.3.8 fsspec-2024.12.0 multiprocess-0.70.16 xxhash-3.5.0

# %%
import os
import random
import numpy as np
import torch
from datasets import Dataset
from torch.utils.data import Subset

SEED = 42
torch.manual_seed(SEED)
random.seed(SEED)
np.random.seed(SEED)

# %%
DATA_DIR = "replace\file\path\for\data\directory"
NUM_LLM_SAMPLES = 25       # samples taken to generate augmented data

train_samples = prepare_datasets(DATA_DIR, seed=SEED)

random.seed(SEED)
llm_samples = random.sample(train_samples, NUM_LLM_SAMPLES)

# %%
def get_few_shot_examples(data, num_examples=3):
    import random
    sampled_data = random.sample(data, min(num_examples, len(data)))
    formatted_examples = "\n".join([
        f"Sentence: {' '.join(tokens)}\nEntities: {labels}"
        for tokens, labels in sampled_data
    ])
    return formatted_examples

# %%
sample_idx = 2
tokens, labels = train_samples[sample_idx]

print("📦 ORIGINAL FORMAT:")
print("Tokens:", tokens)
print("NER Tags:", labels)

print("\n📝 FEW-SHOT FORMAT (from get_few_shot_examples):")
formatted = get_few_shot_examples([train_samples[sample_idx]], num_examples=1)
print(formatted)
# Out:
# 📦 ORIGINAL FORMAT:
# Tokens: ['the', 'district', 'seat', 'is', 'the', 'town', 'parchim', '.']
# NER Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O']
#
# 📝 FEW-SHOT FORMAT (from get_few_shot_examples):
# Sentence: the district seat is the town parchim .
# Entities: ['O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O']

# %%
def generate_prompt_deepseek(original_sentence, labels, use_incontext=False, few_shot_data=None, num_outputs=5):
    entity_guide = """
Entity tagging follows:
- B-<EntityType>: Beginning of entity
- I-<EntityType>: Inside of entity
- O: Outside any entity

Maintain the order and type of entities as in the examples.
"""

    if use_incontext:
        examples = few_shot_data
        prompt = f"""
You are an expert AI designed for generating high-quality training data for Named Entity Recognition (NER).

Task: Create {num_outputs} sentence variations. For each variation:
- Maintain the same number, order, and type of named entities as shown.
- For each generarted - Use the format:
  Sentence: <sentence>
  Entities: <list of entity tags>
- The new sentence (same meaning but rephrased) and The token-level NER tags using the B/I/O scheme
- Give examples without explanations commas or full stops

{entity_guide}

Examples:
{examples}

Input:
Sentence: {original_sentence}
Entity Tags: {labels}

Output:
"""
    else:
          prompt = f"""
Generate {num_outputs} diverse paraphrases of the sentence below, ensuring entity labels remain consistent.

Instructions:
- Maintain the same number, order, and type of named entities as shown.
- Radically alter sentence structure (e.g., voice, clauses, grammar).
- Change non-entity context significantly (e.g., synonyms, temporal/spatial shifts).
- Maintain entity order and types using B/I/O tags.
- Give examples without explanations commas or full stops
- use format
  Sentence: <sentence>
  Entities: <list of entity tags>

{entity_guide}

Original Sentence: {original_sentence}
Original Entity Tags: {labels}

Output:
"""

    return prompt.strip().split("\n"), prompt.strip()

# %%
# Send request to DeepSeek via OpenRouter
def send_prompt_to_deepseek(prompt, model="deepseek/deepseek-chat-v3-0324:free", max_tokens=512, temperature=0.7):
    url = "https://openrouter.ai/api/v1/chat/completions"
    OPENROUTER_API_KEY = "replace-api-key"
    headers = {
        "Authorization": f"Bearer {OPENROUTER_API_KEY}",
        "Content-Type": "application/json"
    }

    payload = {
        "model": model,
        "messages": [{"role": "user", "content": prompt}],
        "max_tokens": max_tokens,
        "temperature": temperature
    }

    print("\n📤 Sending Prompt to DeepSeek via OpenRouter...")
    print("📝 Prompt Preview:\n", prompt)

    response = requests.post(url, headers=headers, json=payload)

    if response.status_code == 200:
        output = response.json()["choices"][0]["message"]["content"]
        print("✅ Response received.")
        return output.strip().split("\n")
    else:
        print(f"❌ Failed to generate. Status Code: {response.status_code}")
        print(response.text)
        return []

# %%
def parse_llm_output(llm_lines):
    results = []
    current_sentence = ""
    current_tags = []

    for line in llm_lines:
        line = line.strip()
        if line.lower().startswith("sentence:"):
            current_sentence = line[len("Sentence:"):].strip()
        elif line.lower().startswith("entities:"):
            tag_line = line[len("Entities:"):].strip()
            try:

                tags = eval(tag_line) if isinstance(tag_line, str) else tag_line
                results.append((current_sentence, tags))
            except:
                continue
        elif line.lower().startswith("entity tags:"):
            tag_line = line[len("Entities:"):].strip()
            try:

                tags = eval(tag_line) if isinstance(tag_line, str) else tag_line
                results.append((current_sentence, tags))
            except:
                continue
    return results

# %%
def generate_augmented_data(original_sentence, labels, use_incontext=False, few_shot_data=None, num_augmentations=5, token_limit=20, verbose=True):
    lines, prompt = generate_prompt_deepseek(
        original_sentence, labels,
        use_incontext=use_incontext,
        few_shot_data=few_shot_data,
        num_outputs=num_augmentations
    )

    if verbose:
        print("\n📝 Prompt Preview:\n", prompt)
        print("\n📤 Sending Prompt to DeepSeek via OpenRouter...")

    try:
        responses = send_prompt_to_deepseek(prompt)
    except Exception as e:
        print("❌ API Call Failed:", str(e))
        return []

    if verbose:
        print("\n✅ Raw Output:\n", "\n".join(responses))

    parsed_results = parse_llm_output(responses)

    for i, (sent, ents) in enumerate(parsed_results):
        print(f"\n✅ [{i+1}] Sentence: {sent}")
        print(f"   Tags: {ents}")

    return parsed_results

# %%
import time

NUM_SAMPLES_LLM = len(llm_samples)
augmented_data = []

for sample_idx in range(NUM_SAMPLES_LLM):
    tokens, labels = llm_samples[sample_idx]
    sentence = " ".join(tokens)

    print(f"Sample {sample_idx + 1}/{NUM_SAMPLES_LLM}:")

    style1_data = generate_augmented_data(
        original_sentence=sentence,
        labels=labels,
        use_incontext=False,
        num_augmentations=5
    )
    time.sleep(5)

    style2_data = generate_augmented_data(
        original_sentence=sentence,
        labels=labels,
        use_incontext=True,
        few_shot_data=get_few_shot_examples(llm_samples, 3),
        num_augmentations=5
    )
    time.sleep(5)

    augmented_data.extend(style1_data + style2_data)
# Out:
# Sample 1/25:
#
# 📝 Prompt Preview:
#  Generate 5 diverse paraphrases of the sentence below, ensuring entity labels remain consistent.
#
# Instructions:
# - Maintain the same number, order, and type of named entities as shown.
# - Radically alter sentence structure (e.g., voice, clauses, grammar).
# - Change non-entity context significantly (e.g., synonyms, temporal/spatial shifts).
# - Maintain entity order and types using B/I/O tags.
# - Give examples without explanations commas or full stops
# - use format
#   Sentence: <sentence>
#   Entities: <list of entity tags>
#
#
# Entity tagging follows:
# - B-<EntityType>: Beginning of entity
# - I-<EntityType>: Inside of entity
# - O: Outside any entity
#
# Maintain the order and type of entities as in the examples.
#
#
# Original Sentence: it was adapted for an episode of night visions , directed by and starring bill pullman .
# Original Entity Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-CW', 'I-CW', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O']
#
# Output:
#
# 📤 Sending Prompt to DeepSeek via OpenRouter...
#
# 📤 Sending Prompt to DeepSeek via OpenRouter...
# 📝 Prompt Preview:
#  Generate 5 diverse paraphrases of the sentence below, ensuring entity labels remain consistent.
#
# Instructions:
# - Maintain the same number, order, and type of named entities as shown.
# - Radically alter sentence structure (e.g., voice, clauses, grammar).
# - Change non-entity context significantly (e.g., synonyms, temporal/spatial shifts).
# - Maintain entity order and types using B/I/O tags.
# - Give examples without explanations commas or full stops
# - use format
#   Sentence: <sentence>
#   Entities: <list of entity tags>
#
#
# Entity tagging follows:
# - B-<EntityType>: Beginning of entity
# - I-<EntityType>: Inside of entity
# - O: Outside any entity
#
# Maintain the order and type of entities as in the examples.
#
#
# Original Sentence: it was adapted for an episode of night visions , directed by and starring bill pullman .
# Original Entity Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-CW', 'I-CW', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O']
#
# Output:
# ✅ Response received.
#
# ✅ Raw Output:
#  1.
# Sentence: an episode of night visions was adapted with bill pullman directing and starring in it
# Entities: ['O', 'O', 'O', 'B-CW', 'I-CW', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O']
#
# 2.
# Sentence: bill pullman directed and starred in the adaptation for night visions as an episode
# Entities: ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-CW', 'I-CW', 'O', 'O', 'O', 'O']
#
# 3.
# Sentence: night visions featured an episode adapted by bill pullman who also directed and starred
# Entities: ['B-CW', 'I-CW', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O']
#
# 4.
# Sentence: directed and starring bill pullman the episode was an adaptation for night visions
# Entities: ['O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-CW', 'I-CW']
#
# 5.
# Sentence: the adaptation into an episode of night visions had bill pullman as director and star
# Entities: ['O', 'O', 'O', 'O', 'O', 'O', 'B-CW', 'I-CW', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']
#
# ✅ [1] Sentence: an episode of night visions was adapted with bill pullman directing and starring in it
#    Tags: ['O', 'O', 'O', 'B-CW', 'I-CW', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O']
#
# ✅ [2] Sentence: bill pullman directed and starred in the adaptation for night visions as an episode
#    Tags: ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-CW', 'I-CW', 'O', 'O', 'O', 'O']
#
# ✅ [3] Sentence: night visions featured an episode adapted by bill pullman who also directed and starred
#    Tags: ['B-CW', 'I-CW', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ✅ [4] Sentence: directed and starring bill pullman the episode was an adaptation for night visions
#    Tags: ['O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-CW', 'I-CW']
#
# ✅ [5] Sentence: the adaptation into an episode of night visions had bill pullman as director and star
#    Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'B-CW', 'I-CW', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']
#
# 📝 Prompt Preview:
#  You are an expert AI designed for generating high-quality training data for Named Entity Recognition (NER).
#
# Task: Create 5 sentence variations. For each variation:
# - Maintain the same number, order, and type of named entities as shown.
# - For each generarted - Use the format:
#   Sentence: <sentence>
#   Entities: <list of entity tags>
# - The new sentence (same meaning but rephrased) and The token-level NER tags using the B/I/O scheme
# - Give examples without explanations commas or full stops
#
#
# Entity tagging follows:
# - B-<EntityType>: Beginning of entity
# - I-<EntityType>: Inside of entity
# - O: Outside any entity
#
# Maintain the order and type of entities as in the examples.
#
#
# Examples:
# Sentence: it lies approximately south of radymno , south east of jarosław , and east of the regional capital rzeszów .
# Entities: ['O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O']
# Sentence: vasilev began his career with pfc slavia sofia , where he played until he was 17 .
# Entities: ['O', 'O', 'O', 'O', 'O', 'B-GRP', 'I-GRP', 'I-GRP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Sentence: martin scorsese serves as one of the executive producers .
# Entities: ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# Input:
# Sentence: it was adapted for an episode of night visions , directed by and starring bill pullman .
# Entity Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-CW', 'I-CW', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O']
#
# Output:
#
# 📤 Sending Prompt to DeepSeek via OpenRouter...
#
# 📤 Sending Prompt to DeepSeek via OpenRouter...
# 📝 Prompt Preview:
#  You are an expert AI designed for generating high-quality training data for Named Entity Recognition (NER).
#
# Task: Create 5 sentence variations. For each variation:
# - Maintain the same number, order, and type of named entities as shown.
# - For each generarted - Use the format:
#   Sentence: <sentence>
#   Entities: <list of entity tags>
# - The new sentence (same meaning but rephrased) and The token-level NER tags using the B/I/O scheme
# - Give examples without explanations commas or full stops
#
#
# Entity tagging follows:
# - B-<EntityType>: Beginning of entity
# - I-<EntityType>: Inside of entity
# - O: Outside any entity
#
# Maintain the order and type of entities as in the examples.
#
#
# Examples:
# Sentence: it lies approximately south of radymno , south east of jarosław , and east of the regional capital rzeszów .
# Entities: ['O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O']
# Sentence: vasilev began his career with pfc slavia sofia , where he played until he was 17 .
# Entities: ['O', 'O', 'O', 'O', 'O', 'B-GRP', 'I-GRP', 'I-GRP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Sentence: martin scorsese serves as one of the executive producers .
# Entities: ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# Input:
# Sentence: it was adapted for an episode of night visions , directed by and starring bill pullman .
# Entity Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-CW', 'I-CW', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O']
#
# Output:
# ✅ Response received.
#
# ✅ Raw Output:
#  Here are five sentence variations with the same entity structure:
#
# 1.
# Sentence: the story was turned into an episode of night visions which was directed by and featured bill pullman
# Entities: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-CW', 'I-CW', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER']
#
# 2.
# Sentence: it became an adaptation for night visions with direction and acting by bill pullman
# Entities: ['O', 'O', 'O', 'O', 'O', 'O', 'B-CW', 'I-CW', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER']
#
# 3.
# Sentence: this was made into a night visions episode directed and starring bill pullman
# Entities: ['O', 'O', 'O', 'O', 'O', 'B-CW', 'I-CW', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER']
#
# 4.
# Sentence: an episode of night visions was adapted featuring direction and acting from bill pullman
# Entities: ['O', 'O', 'O', 'B-CW', 'I-CW', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER']
#
# 5.
# Sentence: the adaptation was done for night visions with bill pullman directing and starring
# Entities: ['O', 'O', 'O', 'O', 'O', 'B-CW', 'I-CW', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O']
#
# Each variation maintains the same number, order, and type of named entities as the original sentence.
#
# ✅ [1] Sentence: the story was turned into an episode of night visions which was directed by and featured bill pullman
#    Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-CW', 'I-CW', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER']
#
# ✅ [2] Sentence: it became an adaptation for night visions with direction and acting by bill pullman
#    Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'B-CW', 'I-CW', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER']
#
# ✅ [3] Sentence: this was made into a night visions episode directed and starring bill pullman
#    Tags: ['O', 'O', 'O', 'O', 'O', 'B-CW', 'I-CW', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER']
#
# ✅ [4] Sentence: an episode of night visions was adapted featuring direction and acting from bill pullman
#    Tags: ['O', 'O', 'O', 'B-CW', 'I-CW', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER']
#
# ✅ [5] Sentence: the adaptation was done for night visions with bill pullman directing and starring
#    Tags: ['O', 'O', 'O', 'O', 'O', 'B-CW', 'I-CW', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O']
# Sample 2/25:
#
# 📝 Prompt Preview:
#  Generate 5 diverse paraphrases of the sentence below, ensuring entity labels remain consistent.
#
# Instructions:
# - Maintain the same number, order, and type of named entities as shown.
# - Radically alter sentence structure (e.g., voice, clauses, grammar).
# - Change non-entity context significantly (e.g., synonyms, temporal/spatial shifts).
# - Maintain entity order and types using B/I/O tags.
# - Give examples without explanations commas or full stops
# - use format
#   Sentence: <sentence>
#   Entities: <list of entity tags>
#
#
# Entity tagging follows:
# - B-<EntityType>: Beginning of entity
# - I-<EntityType>: Inside of entity
# - O: Outside any entity
#
# Maintain the order and type of entities as in the examples.
#
#
# Original Sentence: the roots are sweet , but contain inulin , which gives some people digestive problems .
# Original Entity Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PROD', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# Output:
#
# 📤 Sending Prompt to DeepSeek via OpenRouter...
#
# 📤 Sending Prompt to DeepSeek via OpenRouter...
# 📝 Prompt Preview:
#  Generate 5 diverse paraphrases of the sentence below, ensuring entity labels remain consistent.
#
# Instructions:
# - Maintain the same number, order, and type of named entities as shown.
# - Radically alter sentence structure (e.g., voice, clauses, grammar).
# - Change non-entity context significantly (e.g., synonyms, temporal/spatial shifts).
# - Maintain entity order and types using B/I/O tags.
# - Give examples without explanations commas or full stops
# - use format
#   Sentence: <sentence>
#   Entities: <list of entity tags>
#
#
# Entity tagging follows:
# - B-<EntityType>: Beginning of entity
# - I-<EntityType>: Inside of entity
# - O: Outside any entity
#
# Maintain the order and type of entities as in the examples.
#
#
# Original Sentence: the roots are sweet , but contain inulin , which gives some people digestive problems .
# Original Entity Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PROD', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# Output:
# ✅ Response received.
#
# ✅ Raw Output:
#  1.
# Sentence: Sweetness characterizes the roots though inulin within them causes digestive issues for certain individuals
# Entities: ['O', 'O', 'O', 'O', 'O', 'O', 'B-PROD', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# 2.
# Sentence: While the roots taste sweet inulin present in them leads to digestive discomfort for some people
# Entities: ['O', 'O', 'O', 'O', 'O', 'B-PROD', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# 3.
# Sentence: Digestive problems arise in some from inulin despite the roots having a sweet flavor
# Entities: ['O', 'O', 'O', 'O', 'O', 'B-PROD', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# 4.
# Sentence: The sweet roots harbor inulin an element triggering digestive troubles in certain people
# Entities: ['O', 'O', 'O', 'O', 'B-PROD', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# 5.
# Sentence: Inulin found in the sweet roots is responsible for giving digestive problems to some
# Entities: ['B-PROD', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ✅ [1] Sentence: Sweetness characterizes the roots though inulin within them causes digestive issues for certain individuals
#    Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'B-PROD', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ✅ [2] Sentence: While the roots taste sweet inulin present in them leads to digestive discomfort for some people
#    Tags: ['O', 'O', 'O', 'O', 'O', 'B-PROD', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ✅ [3] Sentence: Digestive problems arise in some from inulin despite the roots having a sweet flavor
#    Tags: ['O', 'O', 'O', 'O', 'O', 'B-PROD', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ✅ [4] Sentence: The sweet roots harbor inulin an element triggering digestive troubles in certain people
#    Tags: ['O', 'O', 'O', 'O', 'B-PROD', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ✅ [5] Sentence: Inulin found in the sweet roots is responsible for giving digestive problems to some
#    Tags: ['B-PROD', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# 📝 Prompt Preview:
#  You are an expert AI designed for generating high-quality training data for Named Entity Recognition (NER).
#
# Task: Create 5 sentence variations. For each variation:
# - Maintain the same number, order, and type of named entities as shown.
# - For each generarted - Use the format:
#   Sentence: <sentence>
#   Entities: <list of entity tags>
# - The new sentence (same meaning but rephrased) and The token-level NER tags using the B/I/O scheme
# - Give examples without explanations commas or full stops
#
#
# Entity tagging follows:
# - B-<EntityType>: Beginning of entity
# - I-<EntityType>: Inside of entity
# - O: Outside any entity
#
# Maintain the order and type of entities as in the examples.
#
#
# Examples:
# Sentence: after 3 three years , it was challenging al-ahram for the status of being the national paper of record .
# Entities: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-GRP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Sentence: the programme was simulcast on itv from around 4 : 30pm .
# Entities: ['O', 'O', 'O', 'O', 'O', 'B-CORP', 'O', 'O', 'O', 'O', 'O', 'O']
# Sentence: it was adapted for an episode of night visions , directed by and starring bill pullman .
# Entities: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-CW', 'I-CW', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O']
#
# Input:
# Sentence: the roots are sweet , but contain inulin , which gives some people digestive problems .
# Entity Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PROD', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# Output:
#
# 📤 Sending Prompt to DeepSeek via OpenRouter...
#
# 📤 Sending Prompt to DeepSeek via OpenRouter...
# 📝 Prompt Preview:
#  You are an expert AI designed for generating high-quality training data for Named Entity Recognition (NER).
#
# Task: Create 5 sentence variations. For each variation:
# - Maintain the same number, order, and type of named entities as shown.
# - For each generarted - Use the format:
#   Sentence: <sentence>
#   Entities: <list of entity tags>
# - The new sentence (same meaning but rephrased) and The token-level NER tags using the B/I/O scheme
# - Give examples without explanations commas or full stops
#
#
# Entity tagging follows:
# - B-<EntityType>: Beginning of entity
# - I-<EntityType>: Inside of entity
# - O: Outside any entity
#
# Maintain the order and type of entities as in the examples.
#
#
# Examples:
# Sentence: after 3 three years , it was challenging al-ahram for the status of being the national paper of record .
# Entities: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-GRP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Sentence: the programme was simulcast on itv from around 4 : 30pm .
# Entities: ['O', 'O', 'O', 'O', 'O', 'B-CORP', 'O', 'O', 'O', 'O', 'O', 'O']
# Sentence: it was adapted for an episode of night visions , directed by and starring bill pullman .
# Entities: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-CW', 'I-CW', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O']
#
# Input:
# Sentence: the roots are sweet , but contain inulin , which gives some people digestive problems .
# Entity Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PROD', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# Output:
# ✅ Response received.
#
# ✅ Raw Output:
#  Here are five sentence variations with matching entity tags:
#
# 1.
# Sentence: the roots taste sweet yet include inulin which can cause digestive issues for some individuals
# Entities: ['O', 'O', 'O', 'O', 'O', 'O', 'B-PROD', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# 2.
# Sentence: these roots are sugary and have inulin leading to digestive troubles for certain people
# Entities: ['O', 'O', 'O', 'O', 'O', 'O', 'B-PROD', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# 3.
# Sentence: sweet in flavor the roots hold inulin causing some to experience digestive discomfort
# Entities: ['O', 'O', 'O', 'O', 'O', 'O', 'B-PROD', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# 4.
# Sentence: despite being sweet the roots contain inulin which may trigger digestive problems in some
# Entities: ['O', 'O', 'O', 'O', 'O', 'O', 'B-PROD', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# 5.
# Sentence: the roots are naturally sweet though they possess inulin resulting in digestive difficulties for a few
# Entities: ['O', 'O', 'O', 'O', 'O', 'O', 'B-PROD', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ✅ [1] Sentence: the roots taste sweet yet include inulin which can cause digestive issues for some individuals
#    Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'B-PROD', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ✅ [2] Sentence: these roots are sugary and have inulin leading to digestive troubles for certain people
#    Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'B-PROD', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ✅ [3] Sentence: sweet in flavor the roots hold inulin causing some to experience digestive discomfort
#    Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'B-PROD', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ✅ [4] Sentence: despite being sweet the roots contain inulin which may trigger digestive problems in some
#    Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'B-PROD', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ✅ [5] Sentence: the roots are naturally sweet though they possess inulin resulting in digestive difficulties for a few
#    Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'B-PROD', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Sample 3/25:
#
# 📝 Prompt Preview:
#  Generate 5 diverse paraphrases of the sentence below, ensuring entity labels remain consistent.
#
# Instructions:
# - Maintain the same number, order, and type of named entities as shown.
# - Radically alter sentence structure (e.g., voice, clauses, grammar).
# - Change non-entity context significantly (e.g., synonyms, temporal/spatial shifts).
# - Maintain entity order and types using B/I/O tags.
# - Give examples without explanations commas or full stops
# - use format
#   Sentence: <sentence>
#   Entities: <list of entity tags>
#
#
# Entity tagging follows:
# - B-<EntityType>: Beginning of entity
# - I-<EntityType>: Inside of entity
# - O: Outside any entity
#
# Maintain the order and type of entities as in the examples.
#
#
# Original Sentence: he currently plays for castres olympique in the top 14 .
# Original Entity Tags: ['O', 'O', 'O', 'O', 'B-GRP', 'I-GRP', 'O', 'O', 'B-CORP', 'I-CORP', 'O']
#
# Output:
#
# 📤 Sending Prompt to DeepSeek via OpenRouter...
#
# 📤 Sending Prompt to DeepSeek via OpenRouter...
# 📝 Prompt Preview:
#  Generate 5 diverse paraphrases of the sentence below, ensuring entity labels remain consistent.
#
# Instructions:
# - Maintain the same number, order, and type of named entities as shown.
# - Radically alter sentence structure (e.g., voice, clauses, grammar).
# - Change non-entity context significantly (e.g., synonyms, temporal/spatial shifts).
# - Maintain entity order and types using B/I/O tags.
# - Give examples without explanations commas or full stops
# - use format
#   Sentence: <sentence>
#   Entities: <list of entity tags>
#
#
# Entity tagging follows:
# - B-<EntityType>: Beginning of entity
# - I-<EntityType>: Inside of entity
# - O: Outside any entity
#
# Maintain the order and type of entities as in the examples.
#
#
# Original Sentence: he currently plays for castres olympique in the top 14 .
# Original Entity Tags: ['O', 'O', 'O', 'O', 'B-GRP', 'I-GRP', 'O', 'O', 'B-CORP', 'I-CORP', 'O']
#
# Output:
# ✅ Response received.
#
# ✅ Raw Output:
#  1.
# Sentence: Castres Olympique is the team he represents now competing in the Top 14
# Entities: ['B-GRP', 'I-GRP', 'O', 'O', 'O', 'O', 'O', 'O', 'B-CORP', 'I-CORP']
#
# 2.
# Sentence: in the Top 14 league his current club is Castres Olympique
# Entities: ['O', 'O', 'B-CORP', 'I-CORP', 'O', 'O', 'O', 'O', 'B-GRP', 'I-GRP']
#
# 3.
# Sentence: his present affiliation with Castres Olympique places him in the Top 14
# Entities: ['O', 'O', 'O', 'O', 'B-GRP', 'I-GRP', 'O', 'O', 'B-CORP', 'I-CORP']
#
# 4.
# Sentence: the Top 14 features him as a player for Castres Olympique at this time
# Entities: ['O', 'B-CORP', 'I-CORP', 'O', 'O', 'O', 'O', 'O', 'B-GRP', 'I-GRP', 'O', 'O', 'O']
#
# 5.
# Sentence: Castres Olympique employs him currently in the Top 14 competition
# Entities: ['B-GRP', 'I-GRP', 'O', 'O', 'O', 'O', 'O', 'B-CORP', 'I-CORP', 'O']
#
# ✅ [1] Sentence: Castres Olympique is the team he represents now competing in the Top 14
#    Tags: ['B-GRP', 'I-GRP', 'O', 'O', 'O', 'O', 'O', 'O', 'B-CORP', 'I-CORP']
#
# ✅ [2] Sentence: in the Top 14 league his current club is Castres Olympique
#    Tags: ['O', 'O', 'B-CORP', 'I-CORP', 'O', 'O', 'O', 'O', 'B-GRP', 'I-GRP']
#
# ✅ [3] Sentence: his present affiliation with Castres Olympique places him in the Top 14
#    Tags: ['O', 'O', 'O', 'O', 'B-GRP', 'I-GRP', 'O', 'O', 'B-CORP', 'I-CORP']
#
# ✅ [4] Sentence: the Top 14 features him as a player for Castres Olympique at this time
#    Tags: ['O', 'B-CORP', 'I-CORP', 'O', 'O', 'O', 'O', 'O', 'B-GRP', 'I-GRP', 'O', 'O', 'O']
#
# ✅ [5] Sentence: Castres Olympique employs him currently in the Top 14 competition
#    Tags: ['B-GRP', 'I-GRP', 'O', 'O', 'O', 'O', 'O', 'B-CORP', 'I-CORP', 'O']
#
# 📝 Prompt Preview:
#  You are an expert AI designed for generating high-quality training data for Named Entity Recognition (NER).
#
# Task: Create 5 sentence variations. For each variation:
# - Maintain the same number, order, and type of named entities as shown.
# - For each generarted - Use the format:
#   Sentence: <sentence>
#   Entities: <list of entity tags>
# - The new sentence (same meaning but rephrased) and The token-level NER tags using the B/I/O scheme
# - Give examples without explanations commas or full stops
#
#
# Entity tagging follows:
# - B-<EntityType>: Beginning of entity
# - I-<EntityType>: Inside of entity
# - O: Outside any entity
#
# Maintain the order and type of entities as in the examples.
#
#
# Examples:
# Sentence: the label produces audio recordings ( cd ) and video ( dvd / blu-ray disc ) .
# Entities: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PROD', 'O', 'B-PROD', 'I-PROD', 'O', 'O']
# Sentence: wood brothers racing morgan shepherd , 1 lap down
# Entities: ['B-CORP', 'I-CORP', 'I-CORP', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O']
# Sentence: the 135ms was the version most commonly seen in competition , and continued to be available until 1954 , when new owners hotchkiss et cie finally called a halt .
# Entities: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-CORP', 'I-CORP', 'I-CORP', 'O', 'O', 'O', 'O', 'O']
#
# Input:
# Sentence: he currently plays for castres olympique in the top 14 .
# Entity Tags: ['O', 'O', 'O', 'O', 'B-GRP', 'I-GRP', 'O', 'O', 'B-CORP', 'I-CORP', 'O']
#
# Output:
#
# 📤 Sending Prompt to DeepSeek via OpenRouter...
#
# 📤 Sending Prompt to DeepSeek via OpenRouter...
# 📝 Prompt Preview:
#  You are an expert AI designed for generating high-quality training data for Named Entity Recognition (NER).
#
# Task: Create 5 sentence variations. For each variation:
# - Maintain the same number, order, and type of named entities as shown.
# - For each generarted - Use the format:
#   Sentence: <sentence>
#   Entities: <list of entity tags>
# - The new sentence (same meaning but rephrased) and The token-level NER tags using the B/I/O scheme
# - Give examples without explanations commas or full stops
#
#
# Entity tagging follows:
# - B-<EntityType>: Beginning of entity
# - I-<EntityType>: Inside of entity
# - O: Outside any entity
#
# Maintain the order and type of entities as in the examples.
#
#
# Examples:
# Sentence: the label produces audio recordings ( cd ) and video ( dvd / blu-ray disc ) .
# Entities: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PROD', 'O', 'B-PROD', 'I-PROD', 'O', 'O']
# Sentence: wood brothers racing morgan shepherd , 1 lap down
# Entities: ['B-CORP', 'I-CORP', 'I-CORP', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O']
# Sentence: the 135ms was the version most commonly seen in competition , and continued to be available until 1954 , when new owners hotchkiss et cie finally called a halt .
# Entities: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-CORP', 'I-CORP', 'I-CORP', 'O', 'O', 'O', 'O', 'O']
#
# Input:
# Sentence: he currently plays for castres olympique in the top 14 .
# Entity Tags: ['O', 'O', 'O', 'O', 'B-GRP', 'I-GRP', 'O', 'O', 'B-CORP', 'I-CORP', 'O']
#
# Output:
# ✅ Response received.
#
# ✅ Raw Output:
#  1.
# Sentence: he is now a player for castres olympique in the top 14
# Entities: ['O', 'O', 'O', 'O', 'O', 'B-GRP', 'I-GRP', 'O', 'O', 'B-CORP', 'I-CORP', 'O']
#
# 2.
# Sentence: at present he represents castres olympique in the top 14
# Entities: ['O', 'O', 'O', 'O', 'B-GRP', 'I-GRP', 'O', 'O', 'B-CORP', 'I-CORP', 'O']
#
# 3.
# Sentence: he currently competes with castres olympique in the top 14
# Entities: ['O', 'O', 'O', 'O', 'B-GRP', 'I-GRP', 'O', 'O', 'B-CORP', 'I-CORP', 'O']
#
# 4.
# Sentence: right now he plays for castres olympique in the top 14
# Entities: ['O', 'O', 'O', 'O', 'B-GRP', 'I-GRP', 'O', 'O', 'B-CORP', 'I-CORP', 'O']
#
# 5.
# Sentence: he is currently signed to castres olympique in the top 14
# Entities: ['O', 'O', 'O', 'O', 'B-GRP', 'I-GRP', 'O', 'O', 'B-CORP', 'I-CORP', 'O']
#
# ✅ [1] Sentence: he is now a player for castres olympique in the top 14
#    Tags: ['O', 'O', 'O', 'O', 'O', 'B-GRP', 'I-GRP', 'O', 'O', 'B-CORP', 'I-CORP', 'O']
#
# ✅ [2] Sentence: at present he represents castres olympique in the top 14
#    Tags: ['O', 'O', 'O', 'O', 'B-GRP', 'I-GRP', 'O', 'O', 'B-CORP', 'I-CORP', 'O']
#
# ✅ [3] Sentence: he currently competes with castres olympique in the top 14
#    Tags: ['O', 'O', 'O', 'O', 'B-GRP', 'I-GRP', 'O', 'O', 'B-CORP', 'I-CORP', 'O']
#
# ✅ [4] Sentence: right now he plays for castres olympique in the top 14
#    Tags: ['O', 'O', 'O', 'O', 'B-GRP', 'I-GRP', 'O', 'O', 'B-CORP', 'I-CORP', 'O']
#
# ✅ [5] Sentence: he is currently signed to castres olympique in the top 14
#    Tags: ['O', 'O', 'O', 'O', 'B-GRP', 'I-GRP', 'O', 'O', 'B-CORP', 'I-CORP', 'O']
# Sample 4/25:
#
# 📝 Prompt Preview:
#  Generate 5 diverse paraphrases of the sentence below, ensuring entity labels remain consistent.
#
# Instructions:
# - Maintain the same number, order, and type of named entities as shown.
# - Radically alter sentence structure (e.g., voice, clauses, grammar).
# - Change non-entity context significantly (e.g., synonyms, temporal/spatial shifts).
# - Maintain entity order and types using B/I/O tags.
# - Give examples without explanations commas or full stops
# - use format
#   Sentence: <sentence>
#   Entities: <list of entity tags>
#
#
# Entity tagging follows:
# - B-<EntityType>: Beginning of entity
# - I-<EntityType>: Inside of entity
# - O: Outside any entity
#
# Maintain the order and type of entities as in the examples.
#
#
# Original Sentence: the journey of the magi by t. s. eliot , drawings by edward mcknight kauffer ( august 1927 )
# Original Entity Tags: ['B-CW', 'I-CW', 'I-CW', 'I-CW', 'I-CW', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O']
#
# Output:
#
# 📤 Sending Prompt to DeepSeek via OpenRouter...
#
# 📤 Sending Prompt to DeepSeek via OpenRouter...
# 📝 Prompt Preview:
#  Generate 5 diverse paraphrases of the sentence below, ensuring entity labels remain consistent.
#
# Instructions:
# - Maintain the same number, order, and type of named entities as shown.
# - Radically alter sentence structure (e.g., voice, clauses, grammar).
# - Change non-entity context significantly (e.g., synonyms, temporal/spatial shifts).
# - Maintain entity order and types using B/I/O tags.
# - Give examples without explanations commas or full stops
# - use format
#   Sentence: <sentence>
#   Entities: <list of entity tags>
#
#
# Entity tagging follows:
# - B-<EntityType>: Beginning of entity
# - I-<EntityType>: Inside of entity
# - O: Outside any entity
#
# Maintain the order and type of entities as in the examples.
#
#
# Original Sentence: the journey of the magi by t. s. eliot , drawings by edward mcknight kauffer ( august 1927 )
# Original Entity Tags: ['B-CW', 'I-CW', 'I-CW', 'I-CW', 'I-CW', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O']
#
# Output:
# ✅ Response received.
#
# ✅ Raw Output:
#  1.
# Sentence: In August 1927, T. S. Eliot wrote "The Journey of the Magi," featuring Edward McKnight Kauffer's drawings
# Entities: ['O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'B-CW', 'I-CW', 'I-CW', 'I-CW', 'I-CW', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O']
#
# 2.
# Sentence: Drawings by Edward McKnight Kauffer accompany T. S. Eliot's "The Journey of the Magi," published in August 1927
# Entities: ['O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'B-CW', 'I-CW', 'I-CW', 'I-CW', 'I-CW', 'O', 'O', 'O', 'O']
#
# 3.
# Sentence: August 1927 saw the release of "The Journey of the Magi," a poem by T. S. Eliot with illustrations from Edward McKnight Kauffer
# Entities: ['O', 'O', 'O', 'O', 'O', 'O', 'B-CW', 'I-CW', 'I-CW', 'I-CW', 'I-CW', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER']
#
# 4.
# Sentence: Edward McKnight Kauffer illustrated T. S. Eliot's "The Journey of the Magi," which debuted in August 1927
# Entities: ['B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'B-CW', 'I-CW', 'I-CW', 'I-CW', 'I-CW', 'O', 'O', 'O', 'O', 'O']
#
# 5.
# Sentence: "The Journey of the Magi," penned by T. S. Eliot and adorned with Edward
#
# ✅ [1] Sentence: In August 1927, T. S. Eliot wrote "The Journey of the Magi," featuring Edward McKnight Kauffer's drawings
#    Tags: ['O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'B-CW', 'I-CW', 'I-CW', 'I-CW', 'I-CW', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O']
#
# ✅ [2] Sentence: Drawings by Edward McKnight Kauffer accompany T. S. Eliot's "The Journey of the Magi," published in August 1927
#    Tags: ['O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'B-CW', 'I-CW', 'I-CW', 'I-CW', 'I-CW', 'O', 'O', 'O', 'O']
#
# ✅ [3] Sentence: August 1927 saw the release of "The Journey of the Magi," a poem by T. S. Eliot with illustrations from Edward McKnight Kauffer
#    Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'B-CW', 'I-CW', 'I-CW', 'I-CW', 'I-CW', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER']
#
# ✅ [4] Sentence: Edward McKnight Kauffer illustrated T. S. Eliot's "The Journey of the Magi," which debuted in August 1927
#    Tags: ['B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'B-CW', 'I-CW', 'I-CW', 'I-CW', 'I-CW', 'O', 'O', 'O', 'O', 'O']
#
# 📝 Prompt Preview:
#  You are an expert AI designed for generating high-quality training data for Named Entity Recognition (NER).
#
# Task: Create 5 sentence variations. For each variation:
# - Maintain the same number, order, and type of named entities as shown.
# - For each generarted - Use the format:
#   Sentence: <sentence>
#   Entities: <list of entity tags>
# - The new sentence (same meaning but rephrased) and The token-level NER tags using the B/I/O scheme
# - Give examples without explanations commas or full stops
#
#
# Entity tagging follows:
# - B-<EntityType>: Beginning of entity
# - I-<EntityType>: Inside of entity
# - O: Outside any entity
#
# Maintain the order and type of entities as in the examples.
#
#
# Examples:
# Sentence: it lies approximately south of radymno , south east of jarosław , and east of the regional capital rzeszów .
# Entities: ['O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O']
# Sentence: the island is north of the country 's capital , malé .
# Entities: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O']
# Sentence: the programme was simulcast on itv from around 4 : 30pm .
# Entities: ['O', 'O', 'O', 'O', 'O', 'B-CORP', 'O', 'O', 'O', 'O', 'O', 'O']
#
# Input:
# Sentence: the journey of the magi by t. s. eliot , drawings by edward mcknight kauffer ( august 1927 )
# Entity Tags: ['B-CW', 'I-CW', 'I-CW', 'I-CW', 'I-CW', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O']
#
# Output:
#
# 📤 Sending Prompt to DeepSeek via OpenRouter...
#
# 📤 Sending Prompt to DeepSeek via OpenRouter...
# 📝 Prompt Preview:
#  You are an expert AI designed for generating high-quality training data for Named Entity Recognition (NER).
#
# Task: Create 5 sentence variations. For each variation:
# - Maintain the same number, order, and type of named entities as shown.
# - For each generarted - Use the format:
#   Sentence: <sentence>
#   Entities: <list of entity tags>
# - The new sentence (same meaning but rephrased) and The token-level NER tags using the B/I/O scheme
# - Give examples without explanations commas or full stops
#
#
# Entity tagging follows:
# - B-<EntityType>: Beginning of entity
# - I-<EntityType>: Inside of entity
# - O: Outside any entity
#
# Maintain the order and type of entities as in the examples.
#
#
# Examples:
# Sentence: it lies approximately south of radymno , south east of jarosław , and east of the regional capital rzeszów .
# Entities: ['O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O']
# Sentence: the island is north of the country 's capital , malé .
# Entities: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O']
# Sentence: the programme was simulcast on itv from around 4 : 30pm .
# Entities: ['O', 'O', 'O', 'O', 'O', 'B-CORP', 'O', 'O', 'O', 'O', 'O', 'O']
#
# Input:
# Sentence: the journey of the magi by t. s. eliot , drawings by edward mcknight kauffer ( august 1927 )
# Entity Tags: ['B-CW', 'I-CW', 'I-CW', 'I-CW', 'I-CW', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O']
#
# Output:
# ✅ Response received.
#
# ✅ Raw Output:
#  1.
# Sentence: the magi 's journey written by t. s. eliot with illustrations by edward mcknight kauffer in august 1927
# Entities: ['B-CW', 'I-CW', 'I-CW', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O']
#
# 2.
# Sentence: t. s. eliot authored the journey of the magi featuring drawings by edward mcknight kauffer dated august 1927
# Entities: ['B-PER', 'I-PER', 'I-PER', 'O', 'B-CW', 'I-CW', 'I-CW', 'I-CW', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']
#
# 3.
# Sentence: edward mcknight kauffer provided artwork for the journey of the magi by t. s. eliot in august 1927
# Entities: ['B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-CW', 'I-CW', 'I-CW', 'I-CW', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']
#
# 4.
# Sentence: the journey of the magi a work by t. s. eliot includes illustrations by edward mcknight kauffer from august 1927
# Entities: ['B-CW', 'I-CW', 'I-CW', 'I-CW', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O']
#
# 5.
# Sentence: t. s. eliot 's the journey of the magi was illustrated by edward mcknight kauffer in august 1927
# Entities: ['B-PER', 'I-PER',
#
# ✅ [1] Sentence: the magi 's journey written by t. s. eliot with illustrations by edward mcknight kauffer in august 1927
#    Tags: ['B-CW', 'I-CW', 'I-CW', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O']
#
# ✅ [2] Sentence: t. s. eliot authored the journey of the magi featuring drawings by edward mcknight kauffer dated august 1927
#    Tags: ['B-PER', 'I-PER', 'I-PER', 'O', 'B-CW', 'I-CW', 'I-CW', 'I-CW', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']
#
# ✅ [3] Sentence: edward mcknight kauffer provided artwork for the journey of the magi by t. s. eliot in august 1927
#    Tags: ['B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-CW', 'I-CW', 'I-CW', 'I-CW', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']
#
# ✅ [4] Sentence: the journey of the magi a work by t. s. eliot includes illustrations by edward mcknight kauffer from august 1927
#    Tags: ['B-CW', 'I-CW', 'I-CW', 'I-CW', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O']
# Sample 5/25:
#
# 📝 Prompt Preview:
#  Generate 5 diverse paraphrases of the sentence below, ensuring entity labels remain consistent.
#
# Instructions:
# - Maintain the same number, order, and type of named entities as shown.
# - Radically alter sentence structure (e.g., voice, clauses, grammar).
# - Change non-entity context significantly (e.g., synonyms, temporal/spatial shifts).
# - Maintain entity order and types using B/I/O tags.
# - Give examples without explanations commas or full stops
# - use format
#   Sentence: <sentence>
#   Entities: <list of entity tags>
#
#
# Entity tagging follows:
# - B-<EntityType>: Beginning of entity
# - I-<EntityType>: Inside of entity
# - O: Outside any entity
#
# Maintain the order and type of entities as in the examples.
#
#
# Original Sentence: an unconfirmed tornado was reported in essex
# Original Entity Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'B-LOC']
#
# Output:
#
# 📤 Sending Prompt to DeepSeek via OpenRouter...
#
# 📤 Sending Prompt to DeepSeek via OpenRouter...
# 📝 Prompt Preview:
#  Generate 5 diverse paraphrases of the sentence below, ensuring entity labels remain consistent.
#
# Instructions:
# - Maintain the same number, order, and type of named entities as shown.
# - Radically alter sentence structure (e.g., voice, clauses, grammar).
# - Change non-entity context significantly (e.g., synonyms, temporal/spatial shifts).
# - Maintain entity order and types using B/I/O tags.
# - Give examples without explanations commas or full stops
# - use format
#   Sentence: <sentence>
#   Entities: <list of entity tags>
#
#
# Entity tagging follows:
# - B-<EntityType>: Beginning of entity
# - I-<EntityType>: Inside of entity
# - O: Outside any entity
#
# Maintain the order and type of entities as in the examples.
#
#
# Original Sentence: an unconfirmed tornado was reported in essex
# Original Entity Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'B-LOC']
#
# Output:
# ✅ Response received.
#
# ✅ Raw Output:
#  1.
# Sentence: Essex experienced reports of a tornado that remains unverified
# Entities: ['B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# 2.
# Sentence: rumors circulated about an unconfirmed tornado striking Essex
# Entities: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC']
#
# 3.
# Sentence: in Essex a tornado was allegedly spotted though confirmation is pending
# Entities: ['O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# 4.
# Sentence: the sighting of a tornado in Essex lacks official confirmation
# Entities: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O']
#
# 5.
# Sentence: Essex may have been hit by an unverified tornado according to witnesses
# Entities: ['B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ✅ [1] Sentence: Essex experienced reports of a tornado that remains unverified
#    Tags: ['B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ✅ [2] Sentence: rumors circulated about an unconfirmed tornado striking Essex
#    Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC']
#
# ✅ [3] Sentence: in Essex a tornado was allegedly spotted though confirmation is pending
#    Tags: ['O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ✅ [4] Sentence: the sighting of a tornado in Essex lacks official confirmation
#    Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O']
#
# ✅ [5] Sentence: Essex may have been hit by an unverified tornado according to witnesses
#    Tags: ['B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# 📝 Prompt Preview:
#  You are an expert AI designed for generating high-quality training data for Named Entity Recognition (NER).
#
# Task: Create 5 sentence variations. For each variation:
# - Maintain the same number, order, and type of named entities as shown.
# - For each generarted - Use the format:
#   Sentence: <sentence>
#   Entities: <list of entity tags>
# - The new sentence (same meaning but rephrased) and The token-level NER tags using the B/I/O scheme
# - Give examples without explanations commas or full stops
#
#
# Entity tagging follows:
# - B-<EntityType>: Beginning of entity
# - I-<EntityType>: Inside of entity
# - O: Outside any entity
#
# Maintain the order and type of entities as in the examples.
#
#
# Examples:
# Sentence: an unconfirmed tornado was reported in essex
# Entities: ['O', 'O', 'O', 'O', 'O', 'O', 'B-LOC']
# Sentence: in 1881 , rice starch , which was important for ironing clothes started to be produced .
# Entities: ['O', 'O', 'O', 'B-PROD', 'B-PROD', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Sentence: the label produces audio recordings ( cd ) and video ( dvd / blu-ray disc ) .
# Entities: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PROD', 'O', 'B-PROD', 'I-PROD', 'O', 'O']
#
# Input:
# Sentence: an unconfirmed tornado was reported in essex
# Entity Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'B-LOC']
#
# Output:
#
# 📤 Sending Prompt to DeepSeek via OpenRouter...
#
# 📤 Sending Prompt to DeepSeek via OpenRouter...
# 📝 Prompt Preview:
#  You are an expert AI designed for generating high-quality training data for Named Entity Recognition (NER).
#
# Task: Create 5 sentence variations. For each variation:
# - Maintain the same number, order, and type of named entities as shown.
# - For each generarted - Use the format:
#   Sentence: <sentence>
#   Entities: <list of entity tags>
# - The new sentence (same meaning but rephrased) and The token-level NER tags using the B/I/O scheme
# - Give examples without explanations commas or full stops
#
#
# Entity tagging follows:
# - B-<EntityType>: Beginning of entity
# - I-<EntityType>: Inside of entity
# - O: Outside any entity
#
# Maintain the order and type of entities as in the examples.
#
#
# Examples:
# Sentence: an unconfirmed tornado was reported in essex
# Entities: ['O', 'O', 'O', 'O', 'O', 'O', 'B-LOC']
# Sentence: in 1881 , rice starch , which was important for ironing clothes started to be produced .
# Entities: ['O', 'O', 'O', 'B-PROD', 'B-PROD', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Sentence: the label produces audio recordings ( cd ) and video ( dvd / blu-ray disc ) .
# Entities: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PROD', 'O', 'B-PROD', 'I-PROD', 'O', 'O']
#
# Input:
# Sentence: an unconfirmed tornado was reported in essex
# Entity Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'B-LOC']
#
# Output:
# ✅ Response received.
#
# ✅ Raw Output:
#  1.
# Sentence: reports emerged of an unverified tornado in essex
# Entities: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC']
#
# 2.
# Sentence: essex experienced an alleged tornado according to reports
# Entities: ['B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
#
# 3.
# Sentence: there was a claim of an unconfirmed tornado in essex
# Entities: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC']
#
# 4.
# Sentence: in essex a possible tornado was reported
# Entities: ['O', 'B-LOC', 'O', 'O', 'O', 'O', 'O']
#
# 5.
# Sentence: a tornado was said to have occurred in essex though unverified
# Entities: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O']
#
# ✅ [1] Sentence: reports emerged of an unverified tornado in essex
#    Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC']
#
# ✅ [2] Sentence: essex experienced an alleged tornado according to reports
#    Tags: ['B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ✅ [3] Sentence: there was a claim of an unconfirmed tornado in essex
#    Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC']
#
# ✅ [4] Sentence: in essex a possible tornado was reported
#    Tags: ['O', 'B-LOC', 'O', 'O', 'O', 'O', 'O']
#
# ✅ [5] Sentence: a tornado was said to have occurred in essex though unverified
#    Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O']
# Sample 6/25:
#
# 📝 Prompt Preview:
#  Generate 5 diverse paraphrases of the sentence below, ensuring entity labels remain consistent.
#
# Instructions:
# - Maintain the same number, order, and type of named entities as shown.
# - Radically alter sentence structure (e.g., voice, clauses, grammar).
# - Change non-entity context significantly (e.g., synonyms, temporal/spatial shifts).
# - Maintain entity order and types using B/I/O tags.
# - Give examples without explanations commas or full stops
# - use format
#   Sentence: <sentence>
#   Entities: <list of entity tags>
#
#
# Entity tagging follows:
# - B-<EntityType>: Beginning of entity
# - I-<EntityType>: Inside of entity
# - O: Outside any entity
#
# Maintain the order and type of entities as in the examples.
#
#
# Original Sentence: wood brothers racing morgan shepherd , 1 lap down
# Original Entity Tags: ['B-CORP', 'I-CORP', 'I-CORP', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O']
#
# Output:
#
# 📤 Sending Prompt to DeepSeek via OpenRouter...
#
# 📤 Sending Prompt to DeepSeek via OpenRouter...
# 📝 Prompt Preview:
#  Generate 5 diverse paraphrases of the sentence below, ensuring entity labels remain consistent.
#
# Instructions:
# - Maintain the same number, order, and type of named entities as shown.
# - Radically alter sentence structure (e.g., voice, clauses, grammar).
# - Change non-entity context significantly (e.g., synonyms, temporal/spatial shifts).
# - Maintain entity order and types using B/I/O tags.
# - Give examples without explanations commas or full stops
# - use format
#   Sentence: <sentence>
#   Entities: <list of entity tags>
#
#
# Entity tagging follows:
# - B-<EntityType>: Beginning of entity
# - I-<EntityType>: Inside of entity
# - O: Outside any entity
#
# Maintain the order and type of entities as in the examples.
#
#
# Original Sentence: wood brothers racing morgan shepherd , 1 lap down
# Original Entity Tags: ['B-CORP', 'I-CORP', 'I-CORP', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O']
#
# Output:
# ✅ Response received.
#
# ✅ Raw Output:
#  1
# Sentence: Despite being 1 lap down Morgan Shepherd continues to represent Wood Brothers Racing
# Entities: ['B-CORP', 'I-CORP', 'I-CORP', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O']
#
# 2
# Sentence: Wood Brothers Racing's Morgan Shepherd trails by 1 lap in the competition
# Entities: ['B-CORP', 'I-CORP', 'I-CORP', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O']
#
# 3
# Sentence: A single lap behind Morgan Shepherd drives for Wood Brothers Racing
# Entities: ['O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'B-CORP', 'I-CORP', 'I-CORP']
#
# 4
# Sentence: Morgan Shepherd of Wood Brothers Racing is currently 1 lap down
# Entities: ['B-PER', 'I-PER', 'O', 'B-CORP', 'I-CORP', 'I-CORP', 'O', 'O', 'O', 'O']
#
# 5
# Sentence: Losing by 1 lap Morgan Shepherd competes under Wood Brothers Racing
# Entities: ['O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'B-CORP', 'I-CORP', 'I-CORP']
#
# ✅ [1] Sentence: Despite being 1 lap down Morgan Shepherd continues to represent Wood Brothers Racing
#    Tags: ['B-CORP', 'I-CORP', 'I-CORP', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O']
#
# ✅ [2] Sentence: Wood Brothers Racing's Morgan Shepherd trails by 1 lap in the competition
#    Tags: ['B-CORP', 'I-CORP', 'I-CORP', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O']
#
# ✅ [3] Sentence: A single lap behind Morgan Shepherd drives for Wood Brothers Racing
#    Tags: ['O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'B-CORP', 'I-CORP', 'I-CORP']
#
# ...
# Entities: ['B-CW', 'I-CW', 'I-CW', 'I-CW', 'O', 'B-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']
# Sentence: vasilev began his career with pfc slavia sofia , where he played until he was 17 .
# Entities: ['O', 'O', 'O', 'O', 'O', 'B-GRP', 'I-GRP', 'I-GRP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Sentence: wood brothers racing morgan shepherd , 1 lap down
# Entities: ['B-CORP', 'I-CORP', 'I-CORP', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O']
#
# Input:
# Sentence: the 135ms was the version most commonly seen in competition , and continued to be available until 1954 , when new owners hotchkiss et cie finally called a halt .
# Entity Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-CORP', 'I-CORP', 'I-CORP', 'O', 'O', 'O', 'O', 'O']
#
# Output:
#
# 📤 Sending Prompt to DeepSeek via OpenRouter...
#
# 📤 Sending Prompt to DeepSeek via OpenRouter...
# 📝 Prompt Preview:
#  You are an expert AI designed for generating high-quality training data for Named Entity Recognition (NER).
#
# Task: Create 5 sentence variations. For each variation:
# - Maintain the same number, order, and type of named entities as shown.
# - For each generarted - Use the format:
#   Sentence: <sentence>
#   Entities: <list of entity tags>
# - The new sentence (same meaning but rephrased) and The token-level NER tags using the B/I/O scheme
# - Give examples without explanations commas or full stops
#
#
# Entity tagging follows:
# - B-<EntityType>: Beginning of entity
# - I-<EntityType>: Inside of entity
# - O: Outside any entity
#
# Maintain the order and type of entities as in the examples.
#
#
# Examples:
# Sentence: i loves you, porgy ( george gershwin , ira gershwin ) – 8 : 57
# Entities: ['B-CW', 'I-CW', 'I-CW', 'I-CW', 'O', 'B-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']
# Sentence: vasilev began his career with pfc slavia sofia , where he played until he was 17 .
# Entities: ['O', 'O', 'O', 'O', 'O', 'B-GRP', 'I-GRP', 'I-GRP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Sentence: wood brothers racing morgan shepherd , 1 lap down
# Entities: ['B-CORP', 'I-CORP', 'I-CORP', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O']
#
# Input:
# Sentence: the 135ms was the version most commonly seen in competition , and continued to be available until 1954 , when new owners hotchkiss et cie finally called a halt .
# Entity Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-CORP', 'I-CORP', 'I-CORP', 'O', 'O', 'O', 'O', 'O']
#
# Output:
# ✅ Response received.
#
# ✅ Raw Output:
#  1.
# Sentence: the 135ms model was most frequently used in competitions and remained on sale until 1954 before hotchkiss et cie decided to discontinue it
# Entities: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-CORP', 'I-CORP', 'I-CORP', 'O', 'O', 'O', 'O']
#
# 2.
# Sentence: in competitions the 135ms was the most popular version staying available until 1954 until hotchkiss et cie stopped production
# Entities: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-CORP', 'I-CORP', 'I-CORP', 'O', 'O', 'O']
#
# 3.
# Sentence: most commonly seen in competition the 135ms version was available up to 1954 when hotchkiss et cie ceased its production
# Entities: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-CORP', 'I-CORP', 'I-CORP', 'O', 'O', 'O', 'O']
#
# 4.
# Sentence: the 135ms was widely used in competitions and remained in production until 1954 when hotchkiss et cie ended its availability
# Entities: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-CORP', 'I-CORP', 'I-CORP', 'O', 'O', 'O', 'O']
#
# 5.
# Sentence: competitions often featured the 135ms which stayed available until 1954 before hotchkiss et cie discontinued it
# Entities: ['O', 'O', 'O', 'O', '
#
# ✅ [1] Sentence: the 135ms model was most frequently used in competitions and remained on sale until 1954 before hotchkiss et cie decided to discontinue it
#    Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-CORP', 'I-CORP', 'I-CORP', 'O', 'O', 'O', 'O']
#
# ✅ [2] Sentence: in competitions the 135ms was the most popular version staying available until 1954 until hotchkiss et cie stopped production
#    Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-CORP', 'I-CORP', 'I-CORP', 'O', 'O', 'O']
#
# ✅ [3] Sentence: most commonly seen in competition the 135ms version was available up to 1954 when hotchkiss et cie ceased its production
#    Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-CORP', 'I-CORP', 'I-CORP', 'O', 'O', 'O', 'O']
#
# ✅ [4] Sentence: the 135ms was widely used in competitions and remained in production until 1954 when hotchkiss et cie ended its availability
#    Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-CORP', 'I-CORP', 'I-CORP', 'O', 'O', 'O', 'O']
# Sample 24/25:
#
# 📝 Prompt Preview:
#  Generate 5 diverse paraphrases of the sentence below, ensuring entity labels remain consistent.
#
# Instructions:
# - Maintain the same number, order, and type of named entities as shown.
# - Radically alter sentence structure (e.g., voice, clauses, grammar).
# - Change non-entity context significantly (e.g., synonyms, temporal/spatial shifts).
# - Maintain entity order and types using B/I/O tags.
# - Give examples without explanations commas or full stops
# - use format
#   Sentence: <sentence>
#   Entities: <list of entity tags>
#
#
# Entity tagging follows:
# - B-<EntityType>: Beginning of entity
# - I-<EntityType>: Inside of entity
# - O: Outside any entity
#
# Maintain the order and type of entities as in the examples.
#
#
# Original Sentence: i loves you, porgy ( george gershwin , ira gershwin ) – 8 : 57
# Original Entity Tags: ['B-CW', 'I-CW', 'I-CW', 'I-CW', 'O', 'B-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']
#
# Output:
#
# 📤 Sending Prompt to DeepSeek via OpenRouter...
#
# 📤 Sending Prompt to DeepSeek via OpenRouter...
# 📝 Prompt Preview:
#  Generate 5 diverse paraphrases of the sentence below, ensuring entity labels remain consistent.
#
# Instructions:
# - Maintain the same number, order, and type of named entities as shown.
# - Radically alter sentence structure (e.g., voice, clauses, grammar).
# - Change non-entity context significantly (e.g., synonyms, temporal/spatial shifts).
# - Maintain entity order and types using B/I/O tags.
# - Give examples without explanations commas or full stops
# - use format
#   Sentence: <sentence>
#   Entities: <list of entity tags>
#
#
# Entity tagging follows:
# - B-<EntityType>: Beginning of entity
# - I-<EntityType>: Inside of entity
# - O: Outside any entity
#
# Maintain the order and type of entities as in the examples.
#
#
# Original Sentence: i loves you, porgy ( george gershwin , ira gershwin ) – 8 : 57
# Original Entity Tags: ['B-CW', 'I-CW', 'I-CW', 'I-CW', 'O', 'B-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']
#
# Output:
# ✅ Response received.
#
# ✅ Raw Output:
#  Here are 5 diverse paraphrases of the sentence with consistent entity labels:
#
# 1. **Sentence**: "Porgy, the song 'i loves you' (written by george gershwin and ira gershwin) lasts 8:57"
#    **Entities**: ['B-CW', 'I-CW', 'I-CW', 'I-CW', 'O', 'B-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']
#
# 2. **Sentence**: "george gershwin and ira gershwin composed 'i loves you, porgy', running 8:57"
#    **Entities**: ['B-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'O', 'B-CW', 'I-CW', 'I-CW', 'I-CW', 'O', 'O', 'O', 'O', 'O']
#
# 3. **Sentence**: "With a duration of 8:57, 'i loves you, porgy' was created by george gershwin and ira gershwin"
#    **Entities**: ['O', 'O', 'O', 'O', 'B-CW', 'I-CW', 'I-CW', 'I-CW', 'O', 'B-PER', 'I-PER', 'O', 'B-PER', 'I-PER']
#
# 4. **Sentence**: "The 8:57-long track 'i loves you, porgy' is credited to george gershwin alongside ira gershwin"
#    **Entities**: ['O', 'O', 'O', 'B-CW', 'I-CW', 'I-CW', 'I-CW', 'O', 'B-PER', 'I-PER', 'O', 'B-PER', 'I-PER']
#
# 5. **Sentence**: "george gershwin and ira gershwin are responsible for 'i loves you, porgy', which spans 8:57"
#    **Entities**: ['B-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'O', 'B-CW', 'I-CW', 'I-CW', 'I-CW', 'O', 'O', 'O
#
# 📝 Prompt Preview:
#  You are an expert AI designed for generating high-quality training data for Named Entity Recognition (NER).
#
# Task: Create 5 sentence variations. For each variation:
# - Maintain the same number, order, and type of named entities as shown.
# - For each generarted - Use the format:
#   Sentence: <sentence>
#   Entities: <list of entity tags>
# - The new sentence (same meaning but rephrased) and The token-level NER tags using the B/I/O scheme
# - Give examples without explanations commas or full stops
#
#
# Entity tagging follows:
# - B-<EntityType>: Beginning of entity
# - I-<EntityType>: Inside of entity
# - O: Outside any entity
#
# Maintain the order and type of entities as in the examples.
#
#
# Examples:
# Sentence: martin scorsese serves as one of the executive producers .
# Entities: ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Sentence: the halliard was rove through an iron ring near the masthead , hoisting a small lug sail , and this was controlled by a sheet and tack .
# Entities: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PROD', 'I-PROD', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Sentence: the programme was simulcast on itv from around 4 : 30pm .
# Entities: ['O', 'O', 'O', 'O', 'O', 'B-CORP', 'O', 'O', 'O', 'O', 'O', 'O']
#
# Input:
# Sentence: i loves you, porgy ( george gershwin , ira gershwin ) – 8 : 57
# Entity Tags: ['B-CW', 'I-CW', 'I-CW', 'I-CW', 'O', 'B-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']
#
# Output:
#
# 📤 Sending Prompt to DeepSeek via OpenRouter...
#
# 📤 Sending Prompt to DeepSeek via OpenRouter...
# 📝 Prompt Preview:
#  You are an expert AI designed for generating high-quality training data for Named Entity Recognition (NER).
#
# Task: Create 5 sentence variations. For each variation:
# - Maintain the same number, order, and type of named entities as shown.
# - For each generarted - Use the format:
#   Sentence: <sentence>
#   Entities: <list of entity tags>
# - The new sentence (same meaning but rephrased) and The token-level NER tags using the B/I/O scheme
# - Give examples without explanations commas or full stops
#
#
# Entity tagging follows:
# - B-<EntityType>: Beginning of entity
# - I-<EntityType>: Inside of entity
# - O: Outside any entity
#
# Maintain the order and type of entities as in the examples.
#
#
# Examples:
# Sentence: martin scorsese serves as one of the executive producers .
# Entities: ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Sentence: the halliard was rove through an iron ring near the masthead , hoisting a small lug sail , and this was controlled by a sheet and tack .
# Entities: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PROD', 'I-PROD', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Sentence: the programme was simulcast on itv from around 4 : 30pm .
# Entities: ['O', 'O', 'O', 'O', 'O', 'B-CORP', 'O', 'O', 'O', 'O', 'O', 'O']
#
# Input:
# Sentence: i loves you, porgy ( george gershwin , ira gershwin ) – 8 : 57
# Entity Tags: ['B-CW', 'I-CW', 'I-CW', 'I-CW', 'O', 'B-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']
#
# Output:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-1fe421654e12> in <cell line: 0>()
#      20
#      21     # Generate Style 2 data
# ---> 22     style2_data = generate_augmented_data(
#      23         original_sentence=sentence,
#      24         labels=labels,
#
# <ipython-input-33-cfc5dc1abf74> in generate_augmented_data(original_sentence, labels, use_incontext, few_shot_data, num_augmentations, token_limit, verbose)
#      12
#      13     try:
# ---> 14         responses = send_prompt_to_deepseek(prompt)
#      15     except Exception as e:
#      16         print("❌ API Call Failed:", str(e))
#
# <ipython-input-31-69d7fe86f640> in send_prompt_to_deepseek(prompt, model, max_tokens, temperature)
#      18     print("📝 Prompt Preview:\n", prompt)
#      19
# ---> 20     response = requests.post(url, headers=headers, json=payload)
#      21
#      22     if response.status_code == 200:
#
# /usr/local/lib/python3.11/dist-packages/requests/api.py in post(url, data, json, **kwargs)
#     113     """
#     114
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#     116
#     117
#
# /usr/local/lib/python3.11/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# /usr/local/lib/python3.11/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.11/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     744
#     745         if not stream:
# --> 746             r.content
#     747
#     748         return r
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in content(self)
#     900                 self._content = None
#     901             else:
# --> 902                 self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     903
#     904         self._content_consumed = True
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in generate()
#     818             if hasattr(self.raw, "stream"):
#     819                 try:
# --> 820                     yield from self.raw.stream(chunk_size, decode_content=True)
#     821                 except ProtocolError as e:
#     822                     raise ChunkedEncodingError(e)
#
# /usr/local/lib/python3.11/dist-packages/urllib3/response.py in stream(self, amt, decode_content)
#    1061         """
#    1062         if self.chunked and self.supports_chunked_reads():
# -> 1063             yield from self.read_chunked(amt, decode_content=decode_content)
#    1064         else:
#    1065             while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
#
# /usr/local/lib/python3.11/dist-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#    1217
#    1218             while True:
# -> 1219                 self._update_chunk_length()
#    1220                 if self.chunk_left == 0:
#    1221                     break
#
# /usr/local/lib/python3.11/dist-packages/urllib3/response.py in _update_chunk_length(self)
#    1136         if self.chunk_left is not None:
#    1137             return None
# -> 1138         line = self._fp.fp.readline()  # type: ignore[union-attr]
#    1139         line = line.split(b";", 1)[0]
#    1140         try:
#
# /usr/lib/python3.11/socket.py in readinto(self, b)
#     716         while True:
#     717             try:
# --> 718                 return self._sock.recv_into(b)
#     719             except timeout:
#     720                 self._timeout_occurred = True
#
# /usr/lib/python3.11/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1312                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1313                   self.__class__)
# -> 1314             return self.read(nbytes, buffer)
#    1315         else:
#    1316             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.11/ssl.py in read(self, len, buffer)
#    1164         try:
#    1165             if buffer is not None:
# -> 1166                 return self._sslobj.read(len, buffer)
#    1167             else:
#    1168                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
def to_conll_format(data):
    """Convert (sentence, tags) tuples to CONLL format lines"""
    conll_lines = []
    for sentence, tags in data:
        tokens = sentence.split()
        for token, tag in zip(tokens, tags):
            # Original CONLL format: Token _ _ NER_Tag
            conll_lines.append(f"{token}\t_\t_\t{tag}")
        conll_lines.append("")
    return conll_lines

# Convert original 100 samples + augmented data
original_conll = []
for tokens, tags in train_samples:  # original 100 samples
    for token, tag in zip(tokens, tags):
        original_conll.append(f"{token}\t_\t_\t{tag}")
    original_conll.append("")

augmented_conll = to_conll_format(augmented_data)

# %%
print(augmented_conll)
# Out:
# ['an\t_\t_\tO', 'episode\t_\t_\tO', 'of\t_\t_\tO', 'night\t_\t_\tB-CW', 'visions\t_\t_\tI-CW', 'was\t_\t_\tO', 'adapted\t_\t_\tO', 'with\t_\t_\tO', 'bill\t_\t_\tO', 'pullman\t_\t_\tO', 'directing\t_\t_\tB-PER', 'and\t_\t_\tI-PER', 'starring\t_\t_\tO', 'in\t_\t_\tO', 'it\t_\t_\tO', '', 'bill\t_\t_\tB-PER', 'pullman\t_\t_\tI-PER', 'directed\t_\t_\tO', 'and\t_\t_\tO', 'starred\t_\t_\tO', 'in\t_\t_\tO', 'the\t_\t_\tO', 'adaptation\t_\t_\tO', 'for\t_\t_\tO', 'night\t_\t_\tB-CW', 'visions\t_\t_\tI-CW', 'as\t_\t_\tO', 'an\t_\t_\tO', 'episode\t_\t_\tO', '', 'night\t_\t_\tB-CW', 'visions\t_\t_\tI-CW', 'featured\t_\t_\tO', 'an\t_\t_\tO', 'episode\t_\t_\tO', 'adapted\t_\t_\tO', 'by\t_\t_\tO', 'bill\t_\t_\tO', 'pullman\t_\t_\
t_\tO', 'the\t_\t_\tO', 'final\t_\t_\tO', 'municipal\t_\t_\tO', 'council\t_\t_\tO', 'was\t_\t_\tO', 'as\t_\t_\tO', 'follows\t_\t_\tO', ':\t_\t_\tO', '', 'the\t_\t_\tO', 'programme\t_\t_\tO', 'was\t_\t_\tO', 'simulcast\t_\t_\tO', 'on\t_\t_\tO', 'itv\t_\t_\tB-CORP', 'from\t_\t_\tO', 'around\t_\t_\tO', '4\t_\t_\tO', ':\t_\t_\tO', '30pm\t_\t_\tO', '.\t_\t_\tO', '', 'the\t_\t_\tO', 'roots\t_\t_\tO', 'are\t_\t_\tO', 'sweet\t_\t_\tO', ',\t_\t_\tO', 'but\t_\t_\tO', 'contain\t_\t_\tO', 'inulin\t_\t_\tB-PROD', ',\t_\t_\tO', 'which\t_\t_\tO', 'gives\t_\t_\tO', 'some\t_\t_\tO', 'people\t_\t_\tO', 'digestive\t_\t_\tO', 'problems\t_\t_\tO', '.\t_\t_\tO', '', 'a\t_\t_\tO', 'report\t_\t_\tO', 'of\t_\t_\tO', 'the\t_\t_\tO', 'death\t_\t_\tO', 'in\t_\t_\tO', 'the\t_\t_\tB-CW', "gentleman's\t_\t_\tI-CW", 'mag ...

# %%
# Combine and save
final_conll = original_conll + augmented_conll

# %%
output_path = "replace\file\path\for\saving\augmented_data"
with open(output_path, "w", encoding="utf-8") as f:
    f.write("\n".join(final_conll))

print(f"✅ Saved {len(final_conll)//15} sentences to {output_path}")
# Out:
# ✅ Saved 339 sentences to /content/drive/MyDrive/augmented_dataset.conll

# %%
def read_conll_file(file_path):
    """Reads a .conll file and returns sentences with their corresponding tags."""
    sentences = []
    ner_tags = []
    tokens = []
    tags = []

    with open(file_path, "r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()

            if not line:
                if tokens:
                    sentences.append(tokens)
                    ner_tags.append(tags)
                    tokens = []
                    tags = []
                continue

            if line.startswith("#"):
                continue

            # Parse each token and its tag (assuming 4-column format: Token _ _ NER_Tag)
            parts = line.split()
            if len(parts) >= 4:
                token, _, _, tag = parts
                tokens.append(token)
                tags.append(tag)

    if tokens:
        sentences.append(tokens)
        ner_tags.append(tags)

    return sentences, ner_tags

def inspect_conll_file(file_path):
    """Reads and inspects a .conll file."""
    sentences, ner_tags = read_conll_file(file_path)

    print(f"📂 File: {file_path}")
    print(f"📊 Total Sentences: {len(sentences)}")
    print(f"📊 Total Tokens: {sum(len(s) for s in sentences)}")

    # Display a preview of the first 3 sentences
    print("\n🔍 Sample Data (First 3 Sentences):")
    for i in range(min(3, len(sentences))):
        print(f"\nSentence {i+1}: {' '.join(sentences[i])}")
        print(f"Tags: {ner_tags[i]}")

file_path = "replace\file\path\for\augmented_data"
inspect_conll_file(file_path)
# Out:
# 📂 File: /content/drive/MyDrive/augmented_dataset.conll
# 📊 Total Sentences: 310
# 📊 Total Tokens: 4778
#
# 🔍 Sample Data (First 3 Sentences):
#
# Sentence 1: his father worked for tate & lyle .
# Tags: ['O', 'O', 'O', 'O', 'B-CORP', 'I-CORP', 'I-CORP', 'O']
#
# Sentence 2: the samples are principally for the tracks produced by rza , and as such , largely cover the earlier years of their career .
# Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# Sentence 3: the district seat is the town parchim .
# Tags: ['O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O']
